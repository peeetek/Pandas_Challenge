# %% [markdown]
#  #  A Whale off the Port(folio)
#  ---
#
#  In this assignment, you'll get to use what you've learned this week to evaluate the performance among various algorithmic, hedge, and mutual fund portfolios and compare them against the S&P TSX 60 Index.

# %%
# Initial imports
import pandas as pd
import numpy as np
import datetime as dt
from pathlib import Path
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# # Data Cleaning
#
# In this section, you will need to read the CSV files into DataFrames and perform any necessary data cleaning steps. After cleaning, combine all DataFrames into a single DataFrame.
#
# Files:
#
# * `whale_returns.csv`: Contains returns of some famous "whale" investors' portfolios.
#
# * `algo_returns.csv`: Contains returns from the in-house trading algorithms from Harold's company.
#
# * `sp_tsx_history.csv`: Contains historical closing prices of the S&P TSX 60 Index.

# %% [markdown]
# ## Whale Returns
#
# Read the Whale Portfolio daily returns and clean the data.

# %%
whale_returns = Path ("Resources/whale_returns.csv")

# %%
whale_returns_df = pd.read_csv(whale_returns, parse_dates=True, index_col="Date", infer_datetime_format=True)

# %%
# Reading whale returns
whale_returns_df.head()
# Out:
#             SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# Date
# 2015-03-02                        NaN                 NaN
# 2015-03-03                  -0.001266           -0.004981
# 2015-03-04                   0.002230            0.003241
# 2015-03-05                   0.004016            0.004076
# 2015-03-06                  -0.007905           -0.003574
#
#             TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC
# Date
# 2015-03-02                          NaN                     NaN
# 2015-03-03                    -0.000496               -0.006569
# 2015-03-04                    -0.002534                0.004213
# 2015-03-05                     0.002355                0.006726
# 2015-03-06                    -0.008481               -0.013098

# %%
# Count nulls
whale_returns_df.isnull().sum()
# Out:
# SOROS FUND MANAGEMENT LLC      1
# PAULSON & CO.INC.              1
# TIGER GLOBAL MANAGEMENT LLC    1
# BERKSHIRE HATHAWAY INC         1
# dtype: int64

# %%
# Drop nulls
whale_returns_df.dropna(inplace=True)
whale_returns_df.isnull().sum()
# Out:
# SOROS FUND MANAGEMENT LLC      0
# PAULSON & CO.INC.              0
# TIGER GLOBAL MANAGEMENT LLC    0
# BERKSHIRE HATHAWAY INC         0
# dtype: int64

# %% [markdown]
# ## Algorithmic Daily Returns
#
# Read the algorithmic daily returns and clean the data.

# %%
# Reading algorithmic returns
algo_returns = Path ("Resources/algo_returns.csv")
algo_returns_df = pd.read_csv(algo_returns, parse_dates=True, index_col="Date", infer_datetime_format=True)
algo_returns_df.columns = ["ALGORITHM 1", "ALGORITHM 2"]

# %%
# Count nulls
algo_returns_df.isnull().sum()
# Out:
# ALGORITHM 1    0
# ALGORITHM 2    6
# dtype: int64

# %%
# Drop nulls
algo_returns_df.dropna(inplace=True)
algo_returns_df.isnull().sum()
# Out:
# ALGORITHM 1    0
# ALGORITHM 2    0
# dtype: int64

# %% [markdown]
# ## S&P TSX 60 Returns
#
# Read the S&P TSX 60 historic closing prices and create a new daily returns DataFrame from the data.

# %%
# Reading S&P TSX 60 Closing Prices
sp_closing_path= Path("Resources/sp_tsx_history.csv")
sp_closing_df=pd.read_csv(sp_closing_path, index_col="Date", infer_datetime_format=True, parse_dates=True)
sp_closing_df.sort_index()
# Out:
#                  Close
# Date
# 2012-10-01  $12,370.19
# 2012-10-02  $12,391.23
# 2012-10-03  $12,359.47
# 2012-10-04  $12,447.68
# 2012-10-05  $12,418.99
# ...                ...
# 2019-12-20  $17,118.44
# 2019-12-23  $17,128.71
# 2019-12-24  $17,180.15
# 2019-12-27  $17,168.21
# 2019-12-30  $17,098.56
#
# [1818 rows x 1 columns]

# %%
# Check Data Types
sp_closing_df.dtypes
# Out:
# Close    object
# dtype: object

# %%
# Fix Data Types
sp_closing_df["Close"] = sp_closing_df["Close"].str.replace("[$,]","").astype(float)
sp_closing_df
# Out:
# /Users/petertran/opt/anaconda3/envs/dev/lib/python3.7/site-packages/ipykernel_launcher.py:2: FutureWarning: The default value of regex will change from True to False in a future version.
#                Close
# Date
# 2012-10-01  12370.19
# 2012-10-02  12391.23
# 2012-10-03  12359.47
# 2012-10-04  12447.68
# 2012-10-05  12418.99
# ...              ...
# 2019-12-20  17118.44
# 2019-12-23  17128.71
# 2019-12-24  17180.15
# 2019-12-27  17168.21
# 2019-12-30  17098.56
#
# [1818 rows x 1 columns]

# %%
# Calculate Daily Returns
sp_returns_df = sp_closing_df.pct_change()
sp_returns_df.head()
# Out:
#                Close
# Date
# 2012-10-01       NaN
# 2012-10-02  0.001701
# 2012-10-03 -0.002563
# 2012-10-04  0.007137
# 2012-10-05 -0.002305

# %%
# Drop nulls
sp_returns_df = sp_returns_df.dropna()
sp_returns_df.isnull().sum()
# Out:
# Close    0
# dtype: int64

# %%
# Rename `Close` Column to be specific to this portfolio.
sp_returns_df=sp_returns_df.rename(columns = {"Close":"S&P TSX 60"})
sp_returns_df.head()
# Out:
#             S&P TSX 60
# Date
# 2012-10-02    0.001701
# 2012-10-03   -0.002563
# 2012-10-04    0.007137
# 2012-10-05   -0.002305
# 2012-10-09   -0.011709

# %% [markdown]
# ## Combine Whale, Algorithmic, and S&P TSX 60 Returns

# %%
# Join Whale Returns, Algorithmic Returns, and the S&P TSX 60 Returns into a single DataFrame with columns for each portfolio's returns.
returns_df = pd.concat([whale_returns_df,algo_returns_df, sp_returns_df], axis="columns", join="inner")
returns_df.head()
# Out:
#             SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# Date
# 2015-03-03                  -0.001266           -0.004981
# 2015-03-04                   0.002230            0.003241
# 2015-03-05                   0.004016            0.004076
# 2015-03-06                  -0.007905           -0.003574
# 2015-03-09                   0.000582            0.004225
#
#             TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC  ALGORITHM 1  \
# Date
# 2015-03-03                    -0.000496               -0.006569    -0.001942
# 2015-03-04                    -0.002534                0.004213    -0.008589
# 2015-03-05                     0.002355                0.006726    -0.000955
# 2015-03-06                    -0.008481               -0.013098    -0.004957
# 2015-03-09                     0.005843               -0.001652    -0.005447
#
#             ALGORITHM 2  S&P TSX 60
# Date
# 2015-03-03    -0.000949   -0.008530
# 2015-03-04     0.002416   -0.003371
# ...

# %% [markdown]
# ---

# %% [markdown]
# # Conduct Quantitative Analysis
#
# In this section, you will calculate and visualize performance and risk metrics for the portfolios.

# %% [markdown]
# ## Performance Anlysis
#
# #### Calculate and Plot the daily returns.

# %%
# Plot daily returns of all portfolios
all_daily_returns = returns_df.plot(title = "Daily Returns", figsize=(20,10))

# %% [markdown]
# # Calculate and Plot cumulative returns.

# %%
# Calculate cumulative returns of all portfolios
cumalative_returns = (1 + returns_df).cumprod()
# Plot cumulative returns
cumalative_returns.plot(figsize = (25,10), title="Cumulative Returns")
# Out:
# <AxesSubplot:title={'center':'Cumulative Returns'}, xlabel='Date'>

# %% [markdown]
# ---

# %% [markdown]
# ## Risk Analysis
#
# Determine the _risk_ of each portfolio:
#
# 1. Create a box plot for each portfolio.
# 2. Calculate the standard deviation for all portfolios.
# 4. Determine which portfolios are riskier than the S&P TSX 60.
# 5. Calculate the Annualized Standard Deviation.

# %% [markdown]
# ### Create a box plot for each portfolio

# %%
# Box plot to visually show risk

whale_boxplot = whale_returns_df.plot.box(figsize = (10,5), title = "Whale Portfolio Risk")
algo_boxplot = algo_returns_df.plot.box(figsize = (10,5), title = "Algo Portfolio Risk")
sp_boxplot = sp_returns_df.plot.box(figsize = (10,5), title = "S&P TSX 60 Portfolio Risk")

# %% [markdown]
# ### Calculate Standard Deviations

# %%
# Calculate the daily standard deviations of all portfolios
all_returns_std = returns_df.std()
all_returns_std
# Out:
# SOROS FUND MANAGEMENT LLC      0.007828
# PAULSON & CO.INC.              0.006982
# TIGER GLOBAL MANAGEMENT LLC    0.010883
# BERKSHIRE HATHAWAY INC         0.012826
# ALGORITHM 1                    0.007589
# ALGORITHM 2                    0.008326
# S&P TSX 60                     0.007034
# dtype: float64

# %% [markdown]
# ### Determine which portfolios are riskier than the S&P TSX 60

# %%
# Calculate  the daily standard deviation of S&P TSX 60
sp_std = all_returns_std["S&P TSX 60"]
#Determine which portfolios are riskier than the S&P TSX 60
index=0
for risk in all_returns_std:
    if risk > sp_std:
        print(f"The {all_returns_std.index[index]} Portfolio has greater risk than S&P TSX 60")
    index+= 1
# Out:
# The SOROS FUND MANAGEMENT LLC Portfolio has greater risk than S&P TSX 60
# The TIGER GLOBAL MANAGEMENT LLC Portfolio has greater risk than S&P TSX 60
# The BERKSHIRE HATHAWAY INC Portfolio has greater risk than S&P TSX 60
# The ALGORITHM 1 Portfolio has greater risk than S&P TSX 60
# The ALGORITHM 2 Portfolio has greater risk than S&P TSX 60

# %% [markdown]
# ### Calculate the Annualized Standard Deviation

# %%
# Calculate the annualized standard deviation (252 trading days)
annualised_std = all_returns_std*np.sqrt(252)
annualised_std
# Out:
# SOROS FUND MANAGEMENT LLC      0.124259
# PAULSON & CO.INC.              0.110841
# TIGER GLOBAL MANAGEMENT LLC    0.172759
# BERKSHIRE HATHAWAY INC         0.203599
# ALGORITHM 1                    0.120470
# ALGORITHM 2                    0.132177
# S&P TSX 60                     0.111664
# dtype: float64

# %% [markdown]
# ---

# %% [markdown]
# ## Rolling Statistics
#
# Risk changes over time. Analyze the rolling statistics for Risk and Beta.
#
# 1. Calculate and plot the rolling standard deviation for all portfolios using a 21-day window.
# 2. Calculate the correlation between each stock to determine which portfolios may mimick the S&P TSX 60.
# 3. Choose one portfolio, then calculate and plot the 60-day rolling beta for it and the S&P TSX 60.

# %% [markdown]
# ### Calculate and plot rolling `std` for all portfolios with 21-day window

# %%
# Calculate the rolling standard deviation for all portfolios using a 21-day window
rolling_all_returns_std = returns_df.rolling(window=21).std()
# Plot the rolling standard deviation
rolling_all_returns_std.plot(figsize=(25,10), title ="Rolling 21 Day STD")
# Out:
# <AxesSubplot:title={'center':'Rolling 21 Day STD'}, xlabel='Date'>

# %% [markdown]
# ### Calculate and plot the correlation

# %%
# Calculate the correlation
correlation = returns_df.corr()

# Display de correlation matrix
sns.heatmap(correlation, vmin=-1, vmax=1, annot=True)
correlation.plot(figsize =(20,5), title = "Correlation of Combined Portfolios")
# Out:
# <AxesSubplot:title={'center':'Correlation of Combined Portfolios'}>

# %% [markdown]
# ### Calculate and Plot Beta for a chosen portfolio and the S&P 60 TSX

# %%
# Calculate covariance of a single portfolio
covariance_tiger = returns_df["TIGER GLOBAL MANAGEMENT LLC"].rolling(window=60).cov(returns_df["S&P TSX 60"])
# Calculate variance of S&P TSX
variance_sp = returns_df["S&P TSX 60"].rolling(window=60).var()
# Computing beta
beta = covariance_tiger / variance_sp
# Plot beta trend
beta.plot(figsize=(20,10), title="Beta Trend for Tiger Global Management LLC")
# Out:
# <AxesSubplot:title={'center':'Beta Trend for Tiger Global Management LLC'}, xlabel='Date'>

# %% [markdown]
# ## Rolling Statistics Challenge: Exponentially Weighted Average
#
# An alternative way to calculate a rolling window is to take the exponentially weighted moving average. This is like a moving window average, but it assigns greater importance to more recent observations. Try calculating the [`ewm`](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.ewm.html) with a 21-day half life for each portfolio, using standard deviation (`std`) as the metric of interest.

# %%
# Use `ewm` to calculate the rolling window
rolling_ewm = returns_df.ewm(halflife=21).std().plot(figsize=(20,10), title = "Exponentially Weighted Average for All Portfolios'")

# %% [markdown]
# ---

# %% [markdown]
# # Sharpe Ratios
# In reality, investment managers and thier institutional investors look at the ratio of return-to-risk, and not just returns alone. After all, if you could invest in one of two portfolios, and each offered the same 10% return, yet one offered lower risk, you'd take that one, right?
#
# ### Using the daily returns, calculate and visualize the Sharpe ratios using a bar plot

# %%
# Annualized Sharpe Ratios
trading_days = returns_df.count()
sharpe_ratios = (returns_df.mean() * trading_days)/(returns_df.std()*np.sqrt(trading_days))

# %%
# Visualize the sharpe ratios as a bar plot
sharpe_ratios.plot(kind="bar", title="Sharpe Ratios")
# Out:
# <AxesSubplot:title={'center':'Sharpe Ratios'}>

# %% [markdown]
# ### Determine whether the algorithmic strategies outperform both the market (S&P TSX 60) and the whales portfolios.
#
# Write your answer here!

# %% [markdown]
# According to the Sharpe Ratio's caclculated above, Algorithm Portfolios 1 & 2 out performed the market and whale portfolios.

# %% [markdown]
# # Create Custom Portfolio
#
# In this section, you will build your own portfolio of stocks, calculate the returns, and compare the results to the Whale Portfolios and the S&P TSX 60.
#
# 1. Choose 3-5 custom stocks with at last 1 year's worth of historic prices and create a DataFrame of the closing prices and dates for each stock.
# 2. Calculate the weighted returns for the portfolio assuming an equal number of shares for each stock.
# 3. Join your portfolio returns to the DataFrame that contains all of the portfolio returns.
# 4. Re-run the performance and risk analysis with your portfolio to see how it compares to the others.
# 5. Include correlation analysis to determine which stocks (if any) are correlated.

# %% [markdown]
# ## Choose 3-5 custom stocks with at last 1 year's worth of historic prices and create a DataFrame of the closing prices and dates for each stock.

# %%
# Reading data from 1st stock
northern_df = Path ("Resources/northern.csv")
northern = pd.read_csv(northern_df, parse_dates=True, index_col="Date", infer_datetime_format=True)
northern.head()
# Out:
#                      Close
# Date
# 2015-01-02 16:00:00   1.51
# 2015-01-05 16:00:00   1.58
# 2015-01-06 16:00:00   1.67
# 2015-01-07 16:00:00   1.71
# 2015-01-08 16:00:00   1.65

# %%
# Reading data from 2nd stock
syrah_df = Path ("Resources/syrah.csv")
syrah = pd.read_csv(syrah_df, parse_dates=True, index_col="Date", infer_datetime_format=True)
syrah.head()
# Out:
#                      Close
# Date
# 2015-01-02 16:00:00   2.96
# 2015-01-05 16:00:00   2.96
# 2015-01-06 16:00:00   2.91
# 2015-01-07 16:00:00   2.87
# 2015-01-08 16:00:00   2.81

# %%
# Reading data from 3rd stock
karoon_df = Path ("Resources/karoon.csv")
karoon = pd.read_csv(karoon_df, parse_dates=True, index_col="Date", infer_datetime_format=True)
karoon.head()
# Out:
#                      Close
# Date
# 2015-01-02 16:00:00   2.26
# 2015-01-05 16:00:00   2.43
# 2015-01-06 16:00:00   2.43
# 2015-01-07 16:00:00   2.32
# 2015-01-08 16:00:00   2.31

# %%
# Combine all stocks in a single DataFrame
my_portfolio = pd.concat([northern,syrah,karoon], axis="columns", join="inner")
my_portfolio.sort_index(inplace=True)
my_portfolio.head()
# Out:
#                      Close  Close  Close
# Date
# 2015-01-02 16:00:00   1.51   2.96   2.26
# 2015-01-05 16:00:00   1.58   2.96   2.43
# 2015-01-06 16:00:00   1.67   2.91   2.43
# 2015-01-07 16:00:00   1.71   2.87   2.32
# 2015-01-08 16:00:00   1.65   2.81   2.31

# %%
# Reset Date index
my_portfolio.index = my_portfolio.index.normalize()

# %%
# Reorganize portfolio data by having a column per symbol
my_portfolio.columns = ['NST', 'SYR', 'KAR']
my_portfolio.head()
# Out:
#              NST   SYR   KAR
# Date
# 2015-01-02  1.51  2.96  2.26
# 2015-01-05  1.58  2.96  2.43
# 2015-01-06  1.67  2.91  2.43
# 2015-01-07  1.71  2.87  2.32
# 2015-01-08  1.65  2.81  2.31

# %%
# Calculate daily returns
my_port_returns = my_portfolio.pct_change()
# Drop NAs
my_returns = my_port_returns.dropna()
# Display sample data
my_returns.head()
# Out:
#                  NST       SYR       KAR
# Date
# 2015-01-05  0.046358  0.000000  0.075221
# 2015-01-06  0.056962 -0.016892  0.000000
# 2015-01-07  0.023952 -0.013746 -0.045267
# 2015-01-08 -0.035088 -0.020906 -0.004310
# 2015-01-09  0.030303  0.010676  0.004329

# %% [markdown]
# ## Calculate the weighted returns for the portfolio assuming an equal number of shares for each stock

# %%
# Set weights
weights = [1/3, 1/3, 1/3]

# Calculate portfolio return
my_weighted_returns = my_returns.dot(weights).rename("MY PORTFOLIO")
# Display sample data
my_weighted_returns.plot(figsize=(20,10), title= 'My Weighted Daily Returns')
# Out:
# <AxesSubplot:title={'center':'My Weighted Daily Returns'}, xlabel='Date'>

# %% [markdown]
# ## Join your portfolio returns to the DataFrame that contains all of the portfolio returns

# %%
# Join your returns DataFrame to the original returns DataFrame
joined_df = pd.concat([returns_df,my_weighted_returns], axis="columns", join="inner")
joined_df.sort_index(inplace=True)
joined_df.head()
# Out:
#             SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# Date
# 2015-03-03                  -0.001266           -0.004981
# 2015-03-04                   0.002230            0.003241
# 2015-03-05                   0.004016            0.004076
# 2015-03-06                  -0.007905           -0.003574
# 2015-03-09                   0.000582            0.004225
#
#             TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC  ALGORITHM 1  \
# Date
# 2015-03-03                    -0.000496               -0.006569    -0.001942
# 2015-03-04                    -0.002534                0.004213    -0.008589
# 2015-03-05                     0.002355                0.006726    -0.000955
# 2015-03-06                    -0.008481               -0.013098    -0.004957
# 2015-03-09                     0.005843               -0.001652    -0.005447
#
#             ALGORITHM 2  S&P TSX 60  MY PORTFOLIO
# Date
# 2015-03-03    -0.000949   -0.008530     -0.026421
# ...

# %%
# Only compare dates where return data exists for all the stocks (drop NaNs)
joined_returns = joined_df.dropna()
joined_returns
# Out:
#             SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# Date
# 2015-03-03                  -0.001266           -0.004981
# 2015-03-04                   0.002230            0.003241
# 2015-03-05                   0.004016            0.004076
# 2015-03-06                  -0.007905           -0.003574
# 2015-03-09                   0.000582            0.004225
# ...                               ...                 ...
# 2019-04-24                   0.002284            0.001009
# 2019-04-26                   0.008149            0.009162
# 2019-04-29                   0.001254            0.002719
# 2019-04-30                  -0.001295           -0.002211
# 2019-05-01                  -0.005847           -0.001341
#
#             TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC  ALGORITHM 1  \
# Date
# 2015-03-03                    -0.000496               -0.006569    -0.001942
# 2015-03-04                    -0.002534                0.004213    -0.008589
# ...

# %% [markdown]
# ## Re-run the risk analysis with your portfolio to see how it compares to the others

# %% [markdown]
# ### Calculate the Annualized Standard Deviation

# %%
# Calculate the annualized `std`
trading_days_joined = joined_returns.count()
joined_std = joined_returns.std()*np.sqrt(trading_days_joined)
joined_std
# Out:
# SOROS FUND MANAGEMENT LLC      0.247245
# PAULSON & CO.INC.              0.221529
# TIGER GLOBAL MANAGEMENT LLC    0.344536
# BERKSHIRE HATHAWAY INC         0.408215
# ALGORITHM 1                    0.241556
# ALGORITHM 2                    0.264332
# S&P TSX 60                     0.222730
# MY PORTFOLIO                   0.630312
# dtype: float64

# %% [markdown]
# ### Calculate and plot rolling `std` with 21-day window

# %%
# Calculate rolling standard deviation
joined_rolling = joined_returns.rolling(window=21).std()

# Plot rolling standard deviation
joined_rolling.plot(figsize=(20,10), title="21 Day Rolling Standard Deviation of Joined Portfolios")
# Out:
# <AxesSubplot:title={'center':'21 Day Rolling Standard Deviation of Joined Portfolios'}, xlabel='Date'>

# %% [markdown]
# ### Calculate and plot the correlation

# %%
# Calculate and plot the correlation
joined_correlation = joined_returns.corr()
sns.heatmap(joined_correlation, vmin=-1, vmax=1, annot=True)
joined_correlation.plot(figsize =(20,5), title = "Correlation of Joined Portfolios")
# Out:
# <AxesSubplot:title={'center':'Correlation of Joined Portfolios'}>

# %% [markdown]
# ### Calculate and Plot the 60-day Rolling Beta for Your Portfolio compared to the S&P 60 TSX

# %%
# Calculate and plot Beta
covariance = joined_returns["MY PORTFOLIO"].rolling(window=60).cov(joined_returns["S&P TSX 60"])
# Calculate variance of S&P TSX
variance = joined_returns["S&P TSX 60"].rolling(window=60).var()
# Computing beta
beta_joined = covariance / variance
# Plot beta trend
beta_joined.plot(title="60 Day Rolling Beta of my Portfolio compred to the S&P 60 TSX", figsize=(20,10))
# Out:
# <AxesSubplot:title={'center':'60 Day Rolling Beta of my Portfolio compred to the S&P 60 TSX'}, xlabel='Date'>

# %% [markdown]
# ### Using the daily returns, calculate and visualize the Sharpe ratios using a bar plot

# %%
# Calculate Annualized Sharpe Ratios
trading_days_joined = joined_returns.count()
sharpe_ratios_joined = (joined_returns.mean()*trading_days_joined)/(joined_returns.std()*np.sqrt(trading_days_joined))

# %%
# Visualize the sharpe ratios as a bar plot
sharpe_ratios_joined.plot(kind="bar", title="Sharpe Ratios of joined portfolios")
# Out:
# <AxesSubplot:title={'center':'Sharpe Ratios of joined portfolios'}>

# %% [markdown]
# ### How does your portfolio do?
#
# Write your answer here!

# %%
My Portfolio had the highest standard deviation in of all portfolios until Late 2018.
My Portfolio was on par with Tiger Global Management but out performed Paulson&Co and Soros Fund Mangement LLC
It also didn't have much of a correlation with the other portfolios, becasue the stock chosen were in a different share markert.
